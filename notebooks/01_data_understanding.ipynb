# %%
import os

print(os.getcwd())
# Out:
# c:\Users\navya\OneDrive\Desktop\Care flow AI\notebooks

# %%
import os

print(os.listdir("../datasets/hospital_patient"))
# Out:
# ['Hospital Patient .csv']

# %%
import pandas as pd
import numpy as np

# %%
patients = pd.read_csv("../datasets/hospital_patient/Hospital Patient .csv")

appointments = pd.read_csv("../datasets/appointments/appointments.csv")

er = pd.read_csv("../datasets/hospital_er/Hospital ER_Data.csv")

patient_flow = pd.read_csv("../datasets/patient_flow/healthcare_analytics_patient_flow_data.csv")

doctors = pd.read_csv("../datasets/doctors/doctors.csv")

departments = pd.read_csv("../datasets/departments/departments.csv")

# %%
patient_flow = pd.read_csv("../datasets/patient_flow/healthcare_analytics_patient_flow_data.csv")

doctors = pd.read_csv("../datasets/doctors/doctors.csv")

departments = pd.read_csv("../datasets/departments/departments.csv")

# %%
print("Patients Dataset :", patients.shape)
print("Appointments Dataset :", appointments.shape)
print("Hospital ER Dataset :", er.shape)
print("Patient Flow Dataset :", patient_flow.shape)
print("Doctors Dataset :", doctors.shape)
print("Departments Dataset :", departments.shape)
# Out:
# Patients Dataset : (984, 15)
# Appointments Dataset : (200, 7)
# Hospital ER Dataset : (9216, 12)
# Patient Flow Dataset : (9216, 11)
# Doctors Dataset : (10, 7)
# Departments Dataset : (10, 2)

# %%
print("Patients")
display(patients.head())

print("Appointments")
display(appointments.head())

print("Hospital ER")
display(er.head())

print("Patient Flow")
display(patient_flow.head())

print("Doctors")
display(doctors.head())

print("Departments")
display(departments.head())
# Out:
# Patients
#    Patient_ID  Age  Gender      Condition               Medication   \
# 0           1   45  Female  Heart Disease               Angioplasty
# 1           2   60    Male       Diabetes           Insulin Therapy
# 2           3   32  Female  Fractured Arm          X-Ray and Splint
# 3           4   75    Male         Stroke    CT Scan and Medication
# 4           5   50  Female         Cancer  Surgery and Chemotherapy
#
#   Admission_Date Discharge_Date Patient_State  Year_of_Admission  \
# 0     07-02-2024     12-02-2024        Kerala               2024
# 1     11-03-2023     14-03-2023           Goa               2023
# 2     02-01-2025     03-01-2025    Maharastra               2025
# 3     30-12-2023     06-01-2024       Manipur               2023
# 4     10-05-2022     20-05-2022       Mizoram               2022
#
#    Length_of_Stay Readmission    Outcome  Satisfaction Insurance_Claimed  \
# 0               5          No  Recovered             4               Yes
# ...

# %%
print("Patients Columns")
print(patients.columns)

print("\nAppointments Columns")
print(appointments.columns)

print("\nHospital ER Columns")
print(er.columns)

print("\nPatient Flow Columns")
print(patient_flow.columns)

print("\nDoctors Columns")
print(doctors.columns)

print("\nDepartments Columns")
print(departments.columns)
# Out:
# Patients Columns
# Index(['Patient_ID', 'Age', 'Gender', 'Condition', 'Medication ',
#        'Admission_Date', 'Discharge_Date', 'Patient_State',
#        'Year_of_Admission', 'Length_of_Stay', 'Readmission', 'Outcome',
#        'Satisfaction', 'Insurance_Claimed', 'Total_Cost'],
#       dtype='str')
#
# Appointments Columns
# Index(['appointment_id', 'patient_id', 'doctor_id', 'appointment_date',
#        'appointment_time', 'reason_for_visit', 'status'],
#       dtype='str')
#
# Hospital ER Columns
# Index(['Patient Id', 'Patient Admission Date', 'Patient First Inital',
#        'Patient Last Name', 'Patient Gender', 'Patient Age', 'Patient Race',
#        'Department Referral', 'Patient Admission Flag',
#        'Patient Satisfaction Score', 'Patient Waittime', 'Patients CM'],
#       dtype='str')
#
# Patient Flow Columns
# Index(['Patient Id', 'Patient Admission Date', 'Patient Admission Time',
#        'Merged', 'Patient Gender', 'Patient Age', 'Patient Race',
# ...

# %%
print("Patients")
patients.info()

print("\nAppointments")
appointments.info()

print("\nHospital ER")
er.info()

print("\nPatient Flow")
patient_flow.info()

print("\nDoctors")
doctors.info()

print("\nDepartments")
departments.info()
# Out:
# Patients
# <class 'pandas.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         984 non-null    int64
#  1   Age                984 non-null    int64
#  2   Gender             984 non-null    str
#  3   Condition          984 non-null    str
#  4   Medication         984 non-null    str
#  5   Admission_Date     984 non-null    str
#  6   Discharge_Date     984 non-null    str
#  7   Patient_State      984 non-null    str
#  8   Year_of_Admission  984 non-null    int64
#  9   Length_of_Stay     984 non-null    int64
#  10  Readmission        984 non-null    str
#  11  Outcome            984 non-null    str
#  12  Satisfaction       984 non-null    int64
#  13  Insurance_Claimed  984 non-null    str
#  14  Total_Cost         984 non-null    int64
# dtypes: int64(6), str(9)
# memory usage: 115.4 KB
#
# Appointments
# ...

# %%
print("Patients")
print(patients.isnull().sum())

print("\nAppointments")
print(appointments.isnull().sum())

print("\nHospital ER")
print(er.isnull().sum())

print("\nPatient Flow")
print(patient_flow.isnull().sum())

print("\nDoctors")
print(doctors.isnull().sum())

print("\nDepartments")
print(departments.isnull().sum())
# Out:
# Patients
# Patient_ID           0
# Age                  0
# Gender               0
# Condition            0
# Medication           0
# Admission_Date       0
# Discharge_Date       0
# Patient_State        0
# Year_of_Admission    0
# Length_of_Stay       0
# Readmission          0
# Outcome              0
# Satisfaction         0
# Insurance_Claimed    0
# Total_Cost           0
# dtype: int64
#
# Appointments
# appointment_id      0
# patient_id          0
# doctor_id           0
# appointment_date    0
# appointment_time    0
# reason_for_visit    0
# status              0
# dtype: int64
#
# Hospital ER
# Patient Id                       0
# Patient Admission Date           0
# Patient First Inital             0
# Patient Last Name                0
# Patient Gender                   0
# Patient Age                      0
# Patient Race                     0
# Department Referral           5400
# Patient Admission Flag           0
# Patient Satisfaction Score    6699
# ...

# %%
print("Patients :", patients.duplicated().sum())
print("Appointments :", appointments.duplicated().sum())
print("Hospital ER :", er.duplicated().sum())
print("Patient Flow :", patient_flow.duplicated().sum())
print("Doctors :", doctors.duplicated().sum())
print("Departments :", departments.duplicated().sum())
# Out:
# Patients : 0
# Appointments : 0
# Hospital ER : 0
# Patient Flow : 0
# Doctors : 0
# Departments : 0

# %%
patients.describe(include="all")
# Out:
#         Patient_ID         Age  Gender      Condition  \
# count   984.000000  984.000000     984            984
# unique         NaN         NaN       2             15
# top            NaN         NaN  Female  Fractured Leg
# freq           NaN         NaN     524             67
# mean    492.500000   53.754065     NaN            NaN
# std     284.200633   14.941135     NaN            NaN
# min       1.000000   25.000000     NaN            NaN
# 25%     246.750000   45.000000     NaN            NaN
# 50%     492.500000   55.000000     NaN            NaN
# 75%     738.250000   65.000000     NaN            NaN
# max     984.000000   78.000000     NaN            NaN
#
#                       Medication  Admission_Date Discharge_Date Patient_State  \
# count                         984            984            984           984
# unique                         15            709            723            30
# top     Cast and Physical Therapy     28-03-2024     20-05-2022        Kerala
# ...
